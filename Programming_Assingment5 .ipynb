# %% [markdown]
# 1.	Write a Python Program to Find LCM?

# %%
n1=int(input("enter the first number : "))
n2=int(input("enter the second number : "))
if n1>n2:
    higher=n1
else:
    higher=n2
a=higher
while True:
    if higher%n1==0 and higher%n2==0:
        print("LCM of ", n1," and ",n2,'is',higher)
        break
    else:
        higher =higher+a
# Out:
# enter the first number : 42
# enter the second number : 32
# LCM of  42  and  32 is 672

# %% [markdown]
# 2.	Write a Python Program to Find HCF?

# %%
# for the hcf we have to follow Euclid's Algorithms

"""
bigger value=(low value) *(x)+remenders
ex-:
64=42*1+16
again-
48=16*3+0
again-
16=0
16 is greatest divider of 64 and42
(64/42
rem=16
times=1)
x=(means-how many time lower value is equal to higher value)
"""
def hcf(a, b):
    if(b == 0):
        return a
    else:
        return hcf(b, a % b)
a=int(input("enter the first number : "))
b=int(input("enter the second number : "))    
print("The gcd of",a, " and ",b," is : ", end="")
print(hcf(a,b))
# Out:
# enter the first number : 9
# enter the second number : 6
# The gcd of 9  and  6  is : 3

# %%
#using library
import math as m
gcd=m.gcd(9,90)
print(gcd)
# Out:
# 9

# %% [markdown]
# 3.	Write a Python Program to Convert Decimal to Binary, Octal and Hexadecimal?

# %%
dec = int(input("Enter a decimal number: "))  
  
print(bin(dec),"in binary.")  
print(oct(dec),"in octal.")  
print(hex(dec),"in hexadecimal.")
# Out:
# Enter a decimal number: 42
# 0b101010 in binary.
# 0o52 in octal.
# 0x2a in hexadecimal.

# %% [markdown]
# 4.	Write a Python Program To Find ASCII value of a character?

# %%
c = input("Enter a character: ")  
  
print("The ASCII value of '" + c + "' is",ord(c))
# Out:
# Enter a character: A
# The ASCII value of 'A' is 65

# %% [markdown]
# 5.	Write a Python Program to Make a Simple Calculator with 4 basic mathematical operations?

# %%
while True:
    choice = input("Enter choice(+,-,*,/): ")
    if choice in ('+', '-', '*', '/'):
        a = float(input("Enter first number: "))
        b = float(input("Enter second number: "))

        if choice == '+':
            print(a, "+", b, "=",a+b )

        elif choice == '-':
            print(a, "-", b, "=",a-b)

        elif choice == '*':
            print(a, "*", b, "=",a*b)

        elif choice == '4':
            print(a, "/", b, "=", a/b)
        break
    else:
        print("Invalid Input")
# Out:
# Enter choice(+,-,*,/): +
# Enter first number: 25
# Enter second number: 5
# 25.0 + 5.0 = 30.0
